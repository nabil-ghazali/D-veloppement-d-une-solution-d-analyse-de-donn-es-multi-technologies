# %%
import json 
import requests

def get_url(id,lang, api_key):
    url = "http:gaetan\"

    params= {
        'id': id,
        'api_key': api_key,
        'lang': lang
    }


    try:
        response= requests.get(url, params = params)
        data= response.json()
        return data
    except requests.exceptions.RequestException as e :
        print(f"Erreur : {e}")

API_KEY : "fgfgtrtz"
users = get_url(2, 'fr', API_KEY)


user_cp = users['id']['adesses'][0]['cp']

# %%
SELECT
    o.oder_id
    c.customer_unique_id
FROM customer c
JOIN orders o ON c.customer_id = o.customer_id
WHERE orders_status = 'delivered'
